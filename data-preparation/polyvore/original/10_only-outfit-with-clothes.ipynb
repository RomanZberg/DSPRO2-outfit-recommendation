# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, SnowballStemmer

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

#nltk.download()  # uncomment this line if you execute this notebook the first time, afterwards you can comment it again

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')

df = pd.DataFrame()
df_train = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/train_no_dup.json')
df_test = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/test_no_dup.json')
df_valid = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/valid_no_dup.json')

df = pd.concat([df_train, df_test, df_valid])
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/blackbook/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/blackbook/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/blackbook/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/blackbook/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                                    name  views  \
# 0                                                Casual   8743
# 1     Being a Vans shoe model with Luke. Idk about t...    188
# 2                   These Chanel bags is a bad habit .x    562
# 3                              Avenger/Supernatural prp   2613
# 4                                             Boho (39)     62
# ...                                                 ...    ...
# 1492                Celebrity Closet: White Shirt Dress    768
# 1493                                               Army    281
# 1494             séance de sport avec Niall #TenueSport     79
# 1495                      Gravity Falls: Wendy Corduroy    519
# 1496         Apples of Gold Jewelry - Black-Akoya-Pearl    553
#
#                                                   items  \
# 0     [{'index': 1, 'name': 'mock neck embroidery su...
# 1     [{'index': 1, 'name': 'nirvana distressed t-sh...
# 2     [{'index': 1, 'name': 'monki singlet', 'price'...
# 3     [{'index': 1, 'name': 'tops', 'price': 18.0, '...
# 4     [{'index': 1, 'name': 'yoins leather sexy v-ne...
# ...                                                 ...
# 1492  [{'index': 1, 'name': 'alexander wang short dr...
# 1493  [{'index': 1, 'name': 'cut shell top', 'price'...
# 1494  [{'index': 1, 'name': 'shorts', 'price': 26.0,...
# 1495  [{'index': 1, 'name': 'plaid shirt', 'price': ...
# 1496  [{'index': 1, 'name': 'pre-owned casadei orang...
#
#                                                   image  likes       date  \
# 0     http://ak1.polyvoreimg.com/cgi/img-set/cid/214...    394  One month
# 1     http://ak1.polyvoreimg.com/cgi/img-set/cid/120...      9  Two years
# 2     http://ak1.polyvoreimg.com/cgi/img-set/cid/143...     32  Two years
# 3     http://ak2.polyvoreimg.com/cgi/img-set/cid/186...     88   One year
# 4     http://ak2.polyvoreimg.com/cgi/img-set/cid/206...      3   5 months
# ...                                                 ...    ...        ...
# 1492  http://ak2.polyvoreimg.com/cgi/img-set/cid/207...    222   5 months
# 1493  http://ak1.polyvoreimg.com/cgi/img-set/cid/187...     30   One year
# 1494  http://ak1.polyvoreimg.com/cgi/img-set/cid/133...      2  Two years
# 1495  http://ak1.polyvoreimg.com/cgi/img-set/cid/216...    207     4 days
# 1496  http://ak1.polyvoreimg.com/cgi/img-set/cid/216...    206     6 days
#
#                                                 set_url     set_id  \
# 0       http://www.polyvore.com/casual/set?id=214181831  214181831
# 1     http://www.polyvore.com/being_vans_shoe_model_...  120161271
# 2     http://www.polyvore.com/these_chanel_bags_is_b...  143656996
# 3     http://www.polyvore.com/avenger_supernatural_p...  186627934
# 4      http://www.polyvore.com/boho_39/set?id=206969379  206969379
# ...                                                 ...        ...
# 1492  http://www.polyvore.com/celebrity_closet_white...  207031876
# 1493      http://www.polyvore.com/army/set?id=187953065  187953065
# 1494  http://www.polyvore.com/s%C3%A9ance_de_sport_a...  133190483
# 1495  http://www.polyvore.com/gravity_falls_wendy_co...  216814895
# 1496  http://www.polyvore.com/apples_gold_jewelry_bl...  216690089
#
#                                                    desc
# 0     A fashion look from January 2017 by beebeely-l...
# 1     A fashion look from April 2014 featuring destr...
# 2                                              12.19.14
# 3     A fashion look from January 2016 by alyssaclai...
# 4     A fashion look from August 2016 by kate-goida ...
# ...                                                 ...
# 1492  A fashion look from August 2016 by arethaman f...
# 1493  A fashion look from January 2016 by catherine-...
# 1494  A fashion look from August 2014 featuring spor...
# 1495  A fashion look from February 2017 by hollowpoi...
# 1496  A fashion look from February 2017 by ramiza-ro...
#
# [21889 rows x 9 columns]

# %%
df["desc"] = df["desc"].apply(lambda x: x.lower())
df["name"] = df["name"].apply(lambda x: x.lower())

# %%
df_outfits = df[
    df['name'].str.contains('outfit') |
    df['desc'].str.contains('outfit')
    ]

print(f'original dataset size: {df.shape[0]}')
print(f'only outfit dataset: {df_outfits.shape[0]}')
print()
print(f'loss only outfit: {df.shape[0] - df_outfits.shape[0]}')
# Out:
# original dataset size: 21889
# only outfit dataset: 773
#
# loss only outfit: 21116

# %%
df_outfits[['desc', 'set_id']]
# Out:
#                                                    desc     set_id
# 0     a fashion look from january 2017 by beebeely-l...  214181831
# 48    obviously you could wear different earrings, s...  138431148
# 92    a beauty collage from february 2016 by the-nam...  190729756
# 94    a fashion look from march 2016 by livesweet fe...  194711828
# 104   #onedirectionoutfits #zaynmalik #1d #onedirect...  136759878
# ...                                                 ...        ...
# 1475  a fashion look from march 2016 by kittyfantast...  193741608
# 1481  a fashion look from june 2016 featuring blue t...  201717504
# 1485  a fashion look from february 2017 by dressedby...  216860218
# 1488  twinkldeals 12% off coupon code: tdcheer (ends...  213177086
# 1492  a fashion look from august 2016 by arethaman f...  207031876
#
# [773 rows x 2 columns]

# %%
stemmer = SnowballStemmer("english")
stop_words = set(stopwords.words('english'))


def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))


def normalize(text):
    tokens = nltk.word_tokenize(text)
    result = [lemmatize_stemming(token) for token in tokens
              if token not in stop_words and len(token) > 3]
    return result


names = df["name"].apply(lambda x: normalize(x))
desc = df['desc'].apply(lambda x: normalize(x))
names
# Out:
# 0                                       [casual]
# 1                 [van, shoe, model, luke, titl]
# 2                           [chanel, bag, habit]
# 3                           [avenger/supernatur]
# 4                                         [boho]
#                           ...
# 1492       [celebr, closet, white, shirt, dress]
# 1493                                      [armi]
# 1494     [séanc, sport, avec, niall, tenuesport]
# 1495            [graviti, fall, wendi, corduroy]
# 1496    [appl, gold, jewelri, black-akoya-pearl]
# Name: name, Length: 21889, dtype: object

# %%
names = pd.DataFrame(names)
names.explode('name').value_counts()
# Out:
# name
# style          1985
# dress          1202
# school          955
# casual          904
# street          895
#                ...
# etsy.com-up       1
# etrala            1
# etheri            1
# ethan             1
# 🤓🌴☀️              1
# Name: count, Length: 7155, dtype: int64

# %%
desc = pd.DataFrame(desc)
desc.explode('desc').value_counts()
# Out:
# desc
# look          20484
# featur        19055
# fashion       17797
# 2016           8776
# 2017           5014
#               ...
# hamptons-         1
# hamsa             1
# hamzy313          1
# hanakales         1
# 😱😍❤️❤️❤️❤️        1
# Name: count, Length: 19292, dtype: int64

# %%
import os

img_folder = '../datasets/raw/Re-PolyVore'

ignore_files = ['.DS_Store']

categorys = list(filter(lambda x: not x in ignore_files, list(os.listdir(img_folder))))
categorys
# Out:
# ['top',
#  'skirt',
#  'eyewear',
#  'legwear',
#  'watches',
#  'dress',
#  'hats',
#  'neckwear',
#  'earrings',
#  'pants',
#  'gloves',
#  'brooch',
#  'hairwear',
#  'rings',
#  'bag',
#  'shoes',
#  'bracelet',
#  'jumpsuit',
#  'necklace',
#  'outwear']

# %%
import re

category_dict = {}

set_ids = []
for category in categorys:
    for image in os.listdir(f'{img_folder}/{category}'):
        set_name = re.sub(r'_\d{1,5}.jpg', '', image)
        set_and_img_index = re.sub(r'.jpg', '', image)
        set_ids.append(set_name)

        category_dict[f'{set_and_img_index}'] = category

set_ids = list(set(set_ids))
print(f'Number of sets: {len(set_ids)}')
# Out:
# Number of sets: 31612

# %%
len(set_ids)
# Out:
# 31612

# %%
category_dict
# Out:
# {'216632321_1': 'top',
#  '210074048_9': 'top',
#  '193742818_3': 'top',
#  '213186129_1': 'top',
#  '217013310_2': 'top',
#  '73482077_1': 'top',
#  '214828138_1': 'top',
#  '215014247_1': 'top',
#  '33621662_2': 'top',
#  '216787432_1': 'top',
#  '76986944_1': 'top',
#  '209410655_1': 'top',
#  '123917074_1': 'top',
#  '96458185_1': 'top',
#  '124674565_1': 'top',
#  '206440830_1': 'top',
#  '176156916_1': 'top',
#  '147881366_1': 'top',
#  '206173504_1': 'top',
#  '216024275_1': 'top',
#  '110329657_1': 'top',
#  '28397038_1': 'top',
#  '208458036_1': 'top',
#  '106404230_1': 'top',
#  '199555694_1': 'top',
#  '45227243_1': 'top',
#  '209603968_1': 'top',
#  '209163192_1': 'top',
#  '180454545_1': 'top',
#  '205029483_1': 'top',
#  '26463645_2': 'top',
#  '200858761_1': 'top',
#  '212037333_1': 'top',
#  '73705216_2': 'top',
#  '214378844_1': 'top',
#  '171130000_2': 'top',
#  '215782232_1': 'top',
#  '190559675_1': 'top',
#  '146175434_1': 'top',
#  '59629122_1': 'top',
#  '39120811_1': 'top',
#  '139273606_1': 'top',
#  '87199115_1': 'top',
#  '132104855_1': 'top',
#  '150452950_1': 'top',
#  '188408686_7': 'top',
#  '32067060_1': 'top',
#  '195446865_1': 'top',
#  '46698084_1': 'top',
#  '103797865_1': 'top',
#  '212392705_1': 'top',
#  '198175424_1': 'top',
#  '112432013_2': 'top',
#  '216219671_1': 'top',
#  '216359124_1': 'top',
#  '190988480_1': 'top',
#  '130650100_1': 'top',
#  '121937914_1': 'top',
#  '201299900_1': 'top',
#  '114205498_1': 'top',
#  '42530563_1': 'top',
#  '86693693_1': 'top',
#  '214361957_1': 'top',
#  '34164592_2': 'top',
#  '49774648_1': 'top',
#  '55917038_1': 'top',
#  '216902171_1': 'top',
#  '157326623_1': 'top',
#  '212156554_1': 'top',
#  '215541536_1': 'top',
#  '79143256_1': 'top',
#  '81483212_1': 'top',
#  '176125066_1': 'top',
#  '37999783_1': 'top',
#  '209508247_1': 'top',
#  '34206696_1': 'top',
#  '175581450_1': 'top',
#  '137863222_1': 'top',
#  '215882403_1': 'top',
#  '11525443_1': 'top',
#  '208935911_2': 'top',
#  '206147397_1': 'top',
#  '213511682_1': 'top',
#  '71698099_1': 'top',
#  '194420137_1': 'top',
#  '140437039_1': 'top',
#  '216068985_1': 'top',
#  '49575473_1': 'top',
#  '103049951_1': 'top',
#  '114707162_1': 'top',
#  '208325808_1': 'top',
#  '188921015_1': 'top',
#  '189584220_1': 'top',
#  '34148502_2': 'top',
#  '158902722_1': 'top',
#  '103723561_1': 'top',
#  '189955090_1': 'top',
#  '216668892_1': 'top',
#  '207060983_2': 'top',
#  '30777211_1': 'top',
#  '215008617_1': 'top',
#  '127708246_6': 'top',
#  '216387076_1': 'top',
#  '213541967_1': 'top',
#  '191037571_1': 'top',
#  '216473850_1': 'top',
#  '122264735_1': 'top',
#  '216952105_2': 'top',
#  '214005484_2': 'top',
#  '184463890_1': 'top',
#  '215879528_1': 'top',
#  '205927977_1': 'top',
#  '62387177_1': 'top',
#  '209296127_1': 'top',
#  '216946216_1': 'top',
#  '127613050_1': 'top',
#  '216788929_1': 'top',
#  '183816612_1': 'top',
#  '119182736_1': 'top',
#  '216133821_1': 'top',
#  ...}

# %% [markdown]
# # Approach 2 - use cleaned dataset

# %%
df = pd.DataFrame()
df_train = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/train_no_dup.json')
df_test = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/test_no_dup.json')
df_valid = pd.read_json('../datasets/raw/polyvore-dataset-master/polyvore/valid_no_dup.json')

df = pd.concat([df_train, df_test, df_valid])

df = df.rename(columns={
    'image': 'outfitImage',
    'likes': 'outfitLikes',
    'index': 'clothingItemIndex',
    'views': 'outfitViews',
    'name': 'outfitName',
    'desc': 'outfitDesc'
})

df = df.explode('items')
df["items"] = df['items'].apply(lambda x: dict(x))
df.drop(columns=['items'])

df_normalized = pd.json_normalize(df['items'])
df_normalized.rename(columns={
    'index': 'clothingItemIndex',
    'likes': 'clothingItemLikes',
    'price': 'clothingItemPrice',
    'categoryid': 'clothingItemCategoryId',
    'image': 'clothingItemImage',
    'name': 'clothingItemName'
}, inplace=True)

df.reset_index(inplace=True, drop=True)
df_normalized.reset_index(inplace=True, drop=True)

df = pd.concat([df, df_normalized], axis=1)

df.drop(columns=['clothingItemImage', 'outfitImage', 'set_url', 'items'], inplace=True)
df.shape
# Out:
# (142480, 11)

# %%
df
# Out:
#                                         outfitName  outfitViews  outfitLikes  \
# 0                                           Casual         8743          394
# 1                                           Casual         8743          394
# 2                                           Casual         8743          394
# 3                                           Casual         8743          394
# 4                                           Casual         8743          394
# ...                                            ...          ...          ...
# 142475               Gravity Falls: Wendy Corduroy          519          207
# 142476  Apples of Gold Jewelry - Black-Akoya-Pearl          553          206
# 142477  Apples of Gold Jewelry - Black-Akoya-Pearl          553          206
# 142478  Apples of Gold Jewelry - Black-Akoya-Pearl          553          206
# 142479  Apples of Gold Jewelry - Black-Akoya-Pearl          553          206
#
#              date     set_id  \
# 0       One month  214181831
# 1       One month  214181831
# 2       One month  214181831
# 3       One month  214181831
# 4       One month  214181831
# ...           ...        ...
# 142475     4 days  216814895
# 142476     6 days  216690089
# 142477     6 days  216690089
# 142478     6 days  216690089
# 142479     6 days  216690089
#
#                                                outfitDesc  clothingItemIndex  \
# 0       A fashion look from January 2017 by beebeely-l...                  1
# 1       A fashion look from January 2017 by beebeely-l...                  2
# 2       A fashion look from January 2017 by beebeely-l...                  3
# 3       A fashion look from January 2017 by beebeely-l...                  4
# 4       A fashion look from January 2017 by beebeely-l...                  5
# ...                                                   ...                ...
# 142475  A fashion look from February 2017 by hollowpoi...                  6
# 142476  A fashion look from February 2017 by ramiza-ro...                  1
# 142477  A fashion look from February 2017 by ramiza-ro...                  2
# 142478  A fashion look from February 2017 by ramiza-ro...                  3
# 142479  A fashion look from February 2017 by ramiza-ro...                  4
#
#                                          clothingItemName  clothingItemPrice  \
# 0                   mock neck embroidery suede sweatshirt               24.0
# 1                           luxe double zip hooded jacket              150.0
# 2             citizens humanity high rise rocket hem jean              248.0
# 3                                   suede tie short boots               37.0
# 4                            cloth travel school backpack               22.0
# ...                                                   ...                ...
# 142475  shearling sheepskin aviator bomber fur hat pea...               -1.0
# 142476  pre-owned casadei orange leather platform sand...              249.0
# 142477                             pearl classic earrings              375.0
# 142478                               oval white opal ring              425.0
# 142479                           black pearl diamond ring              875.0
#
#         clothingItemLikes  clothingItemCategoryId
# 0                      10                    4495
# 1                    2250                      25
# 2                    2437                      27
# 3                       2                     261
# 4                       2                     259
# ...                   ...                     ...
# 142475                  2                      55
# 142476                 63                      46
# 142477                 15                      64
# 142478                  9                      65
# 142479                 15                      65
#
# [142480 rows x 11 columns]

# %% [markdown]
# ## Remove Items which do not have images in the cleaned dataset and add types

# %%
types = []

for index, row in df.iterrows():
    lookup_key = f'{str(row["set_id"])}_{str(row["clothingItemIndex"])}'

    if lookup_key in category_dict:
        types.append(category_dict[lookup_key])
    else:
        types.append(None)

types
# Out:
# ['top',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'pants',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'pants',
#  None,
#  'bag',
#  'hats',
#  'top',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'skirt',
#  'shoes',
#  'earrings',
#  'necklace',
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'necklace',
#  None,
#  'top',
#  'skirt',
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'skirt',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'dress',
#  'top',
#  'outwear',
#  'shoes',
#  'bag',
#  'neckwear',
#  None,
#  None,
#  'pants',
#  'shoes',
#  None,
#  None,
#  None,
#  'bag',
#  'dress',
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  'dress',
#  None,
#  'bag',
#  'watches',
#  None,
#  'rings',
#  None,
#  'outwear',
#  'top',
#  'pants',
#  None,
#  'bag',
#  'necklace',
#  'dress',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  'eyewear',
#  None,
#  None,
#  'top',
#  'skirt',
#  None,
#  'bag',
#  'hats',
#  None,
#  'outwear',
#  None,
#  None,
#  'bag',
#  'necklace',
#  None,
#  'pants',
#  'shoes',
#  'eyewear',
#  'hairwear',
#  'top',
#  'top',
#  'outwear',
#  'pants',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  'bag',
#  'hats',
#  'dress',
#  'outwear',
#  'shoes',
#  'bag',
#  'rings',
#  'earrings',
#  None,
#  None,
#  'dress',
#  'outwear',
#  None,
#  'bag',
#  None,
#  'eyewear',
#  None,
#  None,
#  'dress',
#  'shoes',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  'skirt',
#  'skirt',
#  'skirt',
#  'skirt',
#  'dress',
#  'pants',
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'earrings',
#  None,
#  'top',
#  None,
#  None,
#  'bag',
#  'bracelet',
#  'dress',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  'pants',
#  'shoes',
#  'dress',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'top',
#  None,
#  'pants',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  'dress',
#  None,
#  'bag',
#  'earrings',
#  'eyewear',
#  'dress',
#  'shoes',
#  None,
#  None,
#  'top',
#  'skirt',
#  'shoes',
#  None,
#  'bag',
#  'hats',
#  None,
#  'bag',
#  None,
#  None,
#  'dress',
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  'outwear',
#  None,
#  None,
#  'top',
#  None,
#  None,
#  None,
#  None,
#  'hats',
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  None,
#  'top',
#  None,
#  None,
#  'bag',
#  'earrings',
#  'rings',
#  'hats',
#  'eyewear',
#  None,
#  'top',
#  None,
#  None,
#  'top',
#  None,
#  'pants',
#  'shoes',
#  'bag',
#  'earrings',
#  'hats',
#  None,
#  'top',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'outwear',
#  'pants',
#  'top',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  None,
#  None,
#  None,
#  'dress',
#  'top',
#  'shoes',
#  'bag',
#  'earrings',
#  'bracelet',
#  None,
#  'eyewear',
#  'top',
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'bracelet',
#  'earrings',
#  None,
#  None,
#  'dress',
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  'bag',
#  'eyewear',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'brooch',
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  'eyewear',
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  'pants',
#  None,
#  'bag',
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  None,
#  'necklace',
#  None,
#  None,
#  None,
#  'dress',
#  'shoes',
#  None,
#  'rings',
#  'hats',
#  'neckwear',
#  'eyewear',
#  'top',
#  'pants',
#  None,
#  'bag',
#  None,
#  'eyewear',
#  'top',
#  'outwear',
#  'pants',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'outwear',
#  'top',
#  'outwear',
#  'shoes',
#  'top',
#  None,
#  'shoes',
#  None,
#  None,
#  'top',
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  'top',
#  None,
#  None,
#  None,
#  'watches',
#  'hats',
#  'dress',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'bag',
#  'top',
#  'outwear',
#  'top',
#  'skirt',
#  'shoes',
#  'bag',
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  'skirt',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  'bracelet',
#  'watches',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  'earrings',
#  'dress',
#  'top',
#  'skirt',
#  'shoes',
#  'bag',
#  'gloves',
#  'eyewear',
#  'dress',
#  'outwear',
#  'shoes',
#  None,
#  'bracelet',
#  'necklace',
#  None,
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'shoes',
#  'bag',
#  'shoes',
#  'bag',
#  'watches',
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'skirt',
#  'shoes',
#  'bag',
#  'bracelet',
#  'shoes',
#  'brooch',
#  'rings',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'necklace',
#  'dress',
#  'shoes',
#  'bag',
#  'rings',
#  None,
#  None,
#  None,
#  'outwear',
#  'pants',
#  None,
#  None,
#  'necklace',
#  'earrings',
#  'bracelet',
#  'brooch',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  'dress',
#  'outwear',
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'bag',
#  'bag',
#  None,
#  'top',
#  'skirt',
#  'bag',
#  None,
#  'top',
#  'pants',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  'eyewear',
#  'dress',
#  None,
#  'shoes',
#  'bag',
#  None,
#  'hats',
#  'eyewear',
#  None,
#  'outwear',
#  'shoes',
#  'bag',
#  None,
#  'top',
#  None,
#  'shoes',
#  'watches',
#  None,
#  None,
#  'hats',
#  None,
#  'top',
#  'outwear',
#  None,
#  None,
#  'bag',
#  'top',
#  'outwear',
#  None,
#  'skirt',
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'watches',
#  None,
#  'rings',
#  None,
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'necklace',
#  'hats',
#  None,
#  'eyewear',
#  'top',
#  'pants',
#  'bag',
#  'watches',
#  None,
#  None,
#  'shoes',
#  None,
#  'top',
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  None,
#  'bracelet',
#  'dress',
#  'shoes',
#  None,
#  'top',
#  None,
#  None,
#  'shoes',
#  None,
#  'bag',
#  None,
#  'dress',
#  'shoes',
#  'bag',
#  'earrings',
#  None,
#  None,
#  'outwear',
#  'skirt',
#  'top',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  'top',
#  'pants',
#  None,
#  'bag',
#  'bracelet',
#  None,
#  'eyewear',
#  None,
#  'top',
#  'shoes',
#  'neckwear',
#  'outwear',
#  None,
#  'outwear',
#  None,
#  'shoes',
#  None,
#  'top',
#  'skirt',
#  None,
#  'bag',
#  None,
#  'necklace',
#  None,
#  None,
#  'top',
#  'pants',
#  'outwear',
#  None,
#  None,
#  'top',
#  'outwear',
#  'pants',
#  'shoes',
#  'bag',
#  'bracelet',
#  'watches',
#  'bracelet',
#  'top',
#  None,
#  None,
#  None,
#  'bag',
#  'bracelet',
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  'bracelet',
#  None,
#  None,
#  None,
#  'outwear',
#  'outwear',
#  'top',
#  'pants',
#  'shoes',
#  'hats',
#  'eyewear',
#  None,
#  'top',
#  'outwear',
#  None,
#  None,
#  'bag',
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  'earrings',
#  'top',
#  'skirt',
#  'shoes',
#  'bag',
#  None,
#  'earrings',
#  None,
#  'top',
#  'outwear',
#  'pants',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  'top',
#  None,
#  'outwear',
#  'pants',
#  None,
#  'bag',
#  'eyewear',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  None,
#  'hats',
#  'top',
#  'pants',
#  'shoes',
#  None,
#  None,
#  'earrings',
#  None,
#  None,
#  'top',
#  None,
#  None,
#  None,
#  'necklace',
#  'earrings',
#  'bracelet',
#  'top',
#  None,
#  'shoes',
#  'bag',
#  None,
#  'neckwear',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'dress',
#  'outwear',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'dress',
#  None,
#  'shoes',
#  'bag',
#  'watches',
#  'neckwear',
#  'outwear',
#  'pants',
#  'top',
#  None,
#  'bag',
#  'watches',
#  None,
#  'bracelet',
#  'dress',
#  None,
#  'shoes',
#  None,
#  'necklace',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'earrings',
#  None,
#  'dress',
#  'shoes',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'bag',
#  None,
#  'top',
#  'pants',
#  None,
#  None,
#  None,
#  'hats',
#  None,
#  None,
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'top',
#  'outwear',
#  'skirt',
#  None,
#  'bag',
#  None,
#  None,
#  'outwear',
#  None,
#  'shoes',
#  'bag',
#  'watches',
#  None,
#  None,
#  'dress',
#  None,
#  'bag',
#  'bracelet',
#  None,
#  None,
#  None,
#  None,
#  'outwear',
#  None,
#  None,
#  'neckwear',
#  None,
#  'eyewear',
#  'top',
#  'pants',
#  'shoes',
#  'bag',
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  'bag',
#  'eyewear',
#  'top',
#  None,
#  'shoes',
#  'bag',
#  'earrings',
#  'rings',
#  'hats',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'pants',
#  'dress',
#  None,
#  'bag',
#  'bag',
#  'hats',
#  'eyewear',
#  None,
#  None,
#  None,
#  None,
#  'top',
#  None,
#  None,
#  'bag',
#  'necklace',
#  None,
#  'outwear',
#  'shoes',
#  'bag',
#  None,
#  'top',
#  None,
#  'bag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'dress',
#  'outwear',
#  None,
#  None,
#  None,
#  'necklace',
#  'top',
#  None,
#  None,
#  'pants',
#  'shoes',
#  'bag',
#  'watches',
#  'rings',
#  'top',
#  'pants',
#  None,
#  'bag',
#  'watches',
#  'rings',
#  'rings',
#  'eyewear',
#  None,
#  None,
#  None,
#  'shoes',
#  'bag',
#  'outwear',
#  'pants',
#  None,
#  None,
#  'bracelet',
#  'top',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'top',
#  'outwear',
#  None,
#  'shoes',
#  'bag',
#  'top',
#  'outwear',
#  None,
#  'bag',
#  None,
#  None,
#  ...]

# %%
df.insert(2, "type", types, True)
df
# Out:
#                                         outfitName  outfitViews      type  \
# 0                                           Casual         8743       top
# 1                                           Casual         8743      None
# 2                                           Casual         8743      None
# 3                                           Casual         8743      None
# 4                                           Casual         8743      None
# ...                                            ...          ...       ...
# 142475               Gravity Falls: Wendy Corduroy          519      hats
# 142476  Apples of Gold Jewelry - Black-Akoya-Pearl          553     shoes
# 142477  Apples of Gold Jewelry - Black-Akoya-Pearl          553  earrings
# 142478  Apples of Gold Jewelry - Black-Akoya-Pearl          553      None
# 142479  Apples of Gold Jewelry - Black-Akoya-Pearl          553      None
#
#         outfitLikes       date     set_id  \
# 0               394  One month  214181831
# 1               394  One month  214181831
# 2               394  One month  214181831
# 3               394  One month  214181831
# 4               394  One month  214181831
# ...             ...        ...        ...
# 142475          207     4 days  216814895
# 142476          206     6 days  216690089
# 142477          206     6 days  216690089
# 142478          206     6 days  216690089
# 142479          206     6 days  216690089
#
#                                                outfitDesc  clothingItemIndex  \
# 0       A fashion look from January 2017 by beebeely-l...                  1
# 1       A fashion look from January 2017 by beebeely-l...                  2
# 2       A fashion look from January 2017 by beebeely-l...                  3
# 3       A fashion look from January 2017 by beebeely-l...                  4
# 4       A fashion look from January 2017 by beebeely-l...                  5
# ...                                                   ...                ...
# 142475  A fashion look from February 2017 by hollowpoi...                  6
# 142476  A fashion look from February 2017 by ramiza-ro...                  1
# 142477  A fashion look from February 2017 by ramiza-ro...                  2
# 142478  A fashion look from February 2017 by ramiza-ro...                  3
# 142479  A fashion look from February 2017 by ramiza-ro...                  4
#
#                                          clothingItemName  clothingItemPrice  \
# 0                   mock neck embroidery suede sweatshirt               24.0
# 1                           luxe double zip hooded jacket              150.0
# 2             citizens humanity high rise rocket hem jean              248.0
# 3                                   suede tie short boots               37.0
# 4                            cloth travel school backpack               22.0
# ...                                                   ...                ...
# 142475  shearling sheepskin aviator bomber fur hat pea...               -1.0
# 142476  pre-owned casadei orange leather platform sand...              249.0
# 142477                             pearl classic earrings              375.0
# 142478                               oval white opal ring              425.0
# 142479                           black pearl diamond ring              875.0
#
#         clothingItemLikes  clothingItemCategoryId
# 0                      10                    4495
# 1                    2250                      25
# 2                    2437                      27
# 3                       2                     261
# 4                       2                     259
# ...                   ...                     ...
# 142475                  2                      55
# 142476                 63                      46
# 142477                 15                      64
# 142478                  9                      65
# 142479                 15                      65
#
# [142480 rows x 12 columns]

# %%
df_only_assigned_types = df[df["type"].isna() == False]
df_only_assigned_types
# Out:
#                                                outfitName  outfitViews  \
# 0                                                  Casual         8743
# 7       Being a Vans shoe model with Luke. Idk about t...          188
# 8       Being a Vans shoe model with Luke. Idk about t...          188
# 15                    These Chanel bags is a bad habit .x          562
# 17                    These Chanel bags is a bad habit .x          562
# ...                                                   ...          ...
# 142472                      Gravity Falls: Wendy Corduroy          519
# 142473                      Gravity Falls: Wendy Corduroy          519
# 142475                      Gravity Falls: Wendy Corduroy          519
# 142476         Apples of Gold Jewelry - Black-Akoya-Pearl          553
# 142477         Apples of Gold Jewelry - Black-Akoya-Pearl          553
#
#             type  outfitLikes       date     set_id  \
# 0            top          394  One month  214181831
# 7            top            9  Two years  120161271
# 8          pants            9  Two years  120161271
# 15           top           32  Two years  143656996
# 17         pants           32  Two years  143656996
# ...          ...          ...        ...        ...
# 142472     pants          207     4 days  216814895
# 142473     shoes          207     4 days  216814895
# 142475      hats          207     4 days  216814895
# 142476     shoes          206     6 days  216690089
# 142477  earrings          206     6 days  216690089
#
#                                                outfitDesc  clothingItemIndex  \
# 0       A fashion look from January 2017 by beebeely-l...                  1
# 7       A fashion look from April 2014 featuring destr...                  1
# 8       A fashion look from April 2014 featuring destr...                  2
# 15                                               12.19.14                  1
# 17                                               12.19.14                  3
# ...                                                   ...                ...
# 142472  A fashion look from February 2017 by hollowpoi...                  3
# 142473  A fashion look from February 2017 by hollowpoi...                  4
# 142475  A fashion look from February 2017 by hollowpoi...                  6
# 142476  A fashion look from February 2017 by ramiza-ro...                  1
# 142477  A fashion look from February 2017 by ramiza-ro...                  2
#
#                                          clothingItemName  clothingItemPrice  \
# 0                   mock neck embroidery suede sweatshirt               24.0
# 7                              nirvana distressed t-shirt               10.0
# 8                     rag bone rock w/ black skinny jeans              235.0
# 15                                          monki singlet               16.0
# 17               topshop moto joni high rise skinny jeans               65.0
# ...                                                   ...                ...
# 142472                 closed lizzy mid-rise skinny jeans              150.0
# 142473                                         moto boots              135.0
# 142475  shearling sheepskin aviator bomber fur hat pea...               -1.0
# 142476  pre-owned casadei orange leather platform sand...              249.0
# 142477                             pearl classic earrings              375.0
#
#         clothingItemLikes  clothingItemCategoryId
# 0                      10                    4495
# 7                    1290                      21
# 8                   17406                     237
# 15                  20094                     104
# 17                  23324                     237
# ...                   ...                     ...
# 142472                 19                     237
# 142473                  4                      42
# 142475                  2                      55
# 142476                 63                      46
# 142477                 15                      64
#
# [76543 rows x 12 columns]

# %%
original_number_of_sets = len(list(set(df["set_id"])))
only_assigned_types_sets = len(list(set(df_only_assigned_types["set_id"])))

print(f'original number of sets: {original_number_of_sets}')
print(f'only assigned types number of sets: {only_assigned_types_sets}')
print(f'loss: {original_number_of_sets - only_assigned_types_sets}')
# Out:
# original number of sets: 21889
# only assigned types number of sets: 20546
# loss: 1343

# %% [markdown]
# ## Remove sets, from which items were removed

# %%
# todo: discus if makes sens => alot less data
# removed_items = pd.DataFrame(
#     df[df['set_id'].isin(df_only_assigned_types['set_id'])]['set_id'].value_counts() -
#     df_only_assigned_types['set_id'].value_counts()
# )
#
# set_ids_which_consists_only_out_of_categorized_items = list(
#     set(removed_items[removed_items['count'] < 5]['count'].index))
# df_only_assigned_types = df_only_assigned_types[
#     df_only_assigned_types['set_id'].isin(set_ids_which_consists_only_out_of_categorized_items)
# ]
# #
# print(f'only assigned types number of sets: {only_assigned_types_sets}')
# print(
#     f'only assigned types number of sets (nothing was removed in previous step): {len(set_ids_which_consists_only_out_of_categorized_items)}')
# print(f'loss: {only_assigned_types_sets - len(set_ids_which_consists_only_out_of_categorized_items)}')
# print(f'new number of sets = {len(list(set(df_only_assigned_types["set_id"])))}')
#
# df_only_assigned_types

# %% [markdown]
# ## Remove Sets which have items of the same type

# %%
set_ids_with_duplicated_types = list(
    set(df_only_assigned_types[df_only_assigned_types.duplicated(subset=['set_id', 'type'])]['set_id'])
)

df_only_assigned_types_no_type_duplicates = df_only_assigned_types[
    ~df_only_assigned_types['set_id'].isin(set_ids_with_duplicated_types)]

set_ids_without_duplicates = list(set(df_only_assigned_types_no_type_duplicates['set_id']))

# print(
#     f'only assigned types number: {len(set_ids_which_consists_only_out_of_categorized_items)}'
# )
# print(f'sets with items of same type: {len(set_ids_with_duplicated_types)}')
# print(f'sets with no items of same type: {len(set_ids_without_duplicates)}')
# print(f'loss: {len(set_ids_which_consists_only_out_of_categorized_items) - len(set_ids_without_duplicates)}')

df_only_assigned_types_no_type_duplicates
# Out:
#                                                outfitName  outfitViews  \
# 0                                                  Casual         8743
# 7       Being a Vans shoe model with Luke. Idk about t...          188
# 8       Being a Vans shoe model with Luke. Idk about t...          188
# 15                    These Chanel bags is a bad habit .x          562
# 17                    These Chanel bags is a bad habit .x          562
# ...                                                   ...          ...
# 142462                                               Army          281
# 142463                                               Army          281
# 142464                                               Army          281
# 142476         Apples of Gold Jewelry - Black-Akoya-Pearl          553
# 142477         Apples of Gold Jewelry - Black-Akoya-Pearl          553
#
#             type  outfitLikes       date     set_id  \
# 0            top          394  One month  214181831
# 7            top            9  Two years  120161271
# 8          pants            9  Two years  120161271
# 15           top           32  Two years  143656996
# 17         pants           32  Two years  143656996
# ...          ...          ...        ...        ...
# 142462     shoes           30   One year  187953065
# 142463       bag           30   One year  187953065
# 142464  necklace           30   One year  187953065
# 142476     shoes          206     6 days  216690089
# 142477  earrings          206     6 days  216690089
#
#                                                outfitDesc  clothingItemIndex  \
# 0       A fashion look from January 2017 by beebeely-l...                  1
# 7       A fashion look from April 2014 featuring destr...                  1
# 8       A fashion look from April 2014 featuring destr...                  2
# 15                                               12.19.14                  1
# 17                                               12.19.14                  3
# ...                                                   ...                ...
# 142462  A fashion look from January 2016 by catherine-...                  4
# 142463  A fashion look from January 2016 by catherine-...                  5
# 142464  A fashion look from January 2016 by catherine-...                  6
# 142476  A fashion look from February 2017 by ramiza-ro...                  1
# 142477  A fashion look from February 2017 by ramiza-ro...                  2
#
#                                          clothingItemName  clothingItemPrice  \
# 0                   mock neck embroidery suede sweatshirt               24.0
# 7                              nirvana distressed t-shirt               10.0
# 8                     rag bone rock w/ black skinny jeans              235.0
# 15                                          monki singlet               16.0
# 17               topshop moto joni high rise skinny jeans               65.0
# ...                                                   ...                ...
# 142462             ralph lauren collection canvas sandals              230.0
# 142463  alexander mcqueen hunter green black mini leat...             1010.0
# 142464   forever faux pearl rhinestone statement necklace               18.0
# 142476  pre-owned casadei orange leather platform sand...              249.0
# 142477                             pearl classic earrings              375.0
#
#         clothingItemLikes  clothingItemCategoryId
# 0                      10                    4495
# 7                    1290                      21
# 8                   17406                     237
# 15                  20094                     104
# 17                  23324                     237
# ...                   ...                     ...
# 142462                831                      46
# 142463                 16                      37
# 142464                 66                      62
# 142476                 63                      46
# 142477                 15                      64
#
# [68504 rows x 12 columns]

# %%
set_ids_with_more_than_one_item = pd.DataFrame(df_only_assigned_types_no_type_duplicates['set_id'].value_counts())
set_ids_with_more_than_one_item = set_ids_with_more_than_one_item[set_ids_with_more_than_one_item['count'] > 3].index

df_only_assigned_types_no_type_duplicates = df_only_assigned_types_no_type_duplicates[
    df_only_assigned_types_no_type_duplicates['set_id'].isin(set_ids_with_more_than_one_item)]

# %% [markdown]
# k

# %%
print(f'loss: {df_only_assigned_types.shape[0] - df_only_assigned_types_no_type_duplicates.shape[0]}')

df_only_assigned_types_no_type_duplicates['set_id'].value_counts()
# Out:
# loss: 29233
# set_id
# 197950503    8
# 196961190    8
# 164807766    8
# 169398378    8
# 148095972    8
#             ..
# 204985346    4
# 213594954    4
# 214596822    4
# 215967127    4
# 187504854    4
# Name: count, Length: 9837, dtype: int64

# %%
import random


def display_outfit(df, n=20):
    all_cleaned_set_ids = list(set(df['set_id']))
    set_ids = random.sample(all_cleaned_set_ids, n)
    outfit_count = 0
    print(f'random sample of {n} outfits from a total of {len(all_cleaned_set_ids)}')

    for set_id in set_ids:

        items = df[df['set_id'] == set_id]

        img_index = 0
        f, axarr = plt.subplots(1, len(items))

        for index, item in items.iterrows():
            img = mpimg.imread(
                f'../datasets/raw/images/{str(set_id)}/{str(item["clothingItemIndex"])}.jpg'
            )
            ax = axarr[img_index]

            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)

            # X AXIS -BORDER
            ax.spines['bottom'].set_visible(False)
            # BLUE
            ax.set_xticklabels([])
            # RED
            ax.set_xticks([])
            # RED AND BLUE TOGETHER
            ax.axes.get_xaxis().set_visible(False)

            # Y AXIS -BORDER
            ax.spines['left'].set_visible(False)
            # YELLOW
            ax.set_yticklabels([])
            # GREEN
            ax.set_yticks([])
            # YELLOW AND GREEN TOGHETHER
            ax.axes.get_yaxis().set_visible(False)

            ax.imshow(img)

            img_index += 1

        outfit_count += 1

        if outfit_count >= n:
            break


display_outfit(df_only_assigned_types_no_type_duplicates)
# Out:
# random sample of 20 outfits from a total of 9837
